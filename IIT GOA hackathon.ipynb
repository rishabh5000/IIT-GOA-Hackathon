# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (3.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.26.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.14.1)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import TimeSeriesSplit, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import xgboost as xgb

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')

train_path = '/content/drive/MyDrive/IITGOA/train.csv'
test_path = '/content/drive/MyDrive/IITGOA/sample_test.csv'
oil_path = '/content/drive/MyDrive/IITGOA/oil.csv'
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
oil = pd.read_csv(oil_path)

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2020-01-01         NaN
# 1     2020-01-02       93.14
# 2     2020-01-03       92.97
# 3     2020-01-04       93.12
# 4     2020-01-07       93.20
# ...          ...         ...
# 1039  2023-12-26         NaN
# 1040  2023-12-27       52.82
# 1041  2023-12-28       54.01
# 1042  2023-12-29       53.80
# 1043  2023-12-30       53.75
#
# [1044 rows x 2 columns]

# %%
test
# Out:
#             id        date  store_nbr                      family  onpromotion
# 0      2596374  2024-01-01          1                  AUTOMOTIVE            0
# 1      2596375  2024-01-01          1                   BABY CARE            0
# 2      2596376  2024-01-01          1                      BEAUTY            0
# 3      2596377  2024-01-01          1                   BEVERAGES            0
# 4      2596378  2024-01-01          1                       BOOKS            0
# ...        ...         ...        ...                         ...          ...
# 26725  2623099  2024-01-15          9                     POULTRY            1
# 26726  2623100  2024-01-15          9              PREPARED FOODS            1
# 26727  2623101  2024-01-15          9                     PRODUCE            7
# 26728  2623102  2024-01-15          9  SCHOOL AND OFFICE SUPPLIES            0
# 26729  2623103  2024-01-15          9                     SEAFOOD            1
#
# [26730 rows x 5 columns]

# %%
train_merged = train.merge(oil, on='date', how='left')

# %%
train_merged
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2020-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2020-01-01          1                   BABY CARE     0.000
# 2              2  2020-01-01          1                      BEAUTY     0.000
# 3              3  2020-01-01          1                   BEVERAGES     0.000
# 4              4  2020-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 2596369  2596369  2023-12-31          9                     POULTRY   687.853
# 2596370  2596370  2023-12-31          9              PREPARED FOODS   100.405
# 2596371  2596371  2023-12-31          9                     PRODUCE  3091.356
# 2596372  2596372  2023-12-31          9  SCHOOL AND OFFICE SUPPLIES     2.000
# 2596373  2596373  2023-12-31          9                     SEAFOOD    13.000
#
#          onpromotion  dcoilwtico
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# ...              ...         ...
# 2596369            1         NaN
# 2596370            1         NaN
# 2596371            3         NaN
# 2596372            0         NaN
# 2596373            2         NaN
#
# [2596374 rows x 7 columns]

# %%
missing_dates = train[~train['date'].isin(oil['date'])]

# %%
oil['dcoilwtico'] = oil['dcoilwtico'].fillna(method='ffill')
train = train.merge(oil, how='left', on='date')

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2020-01-01         NaN
# 1     2020-01-02       93.14
# 2     2020-01-03       92.97
# 3     2020-01-04       93.12
# 4     2020-01-07       93.20
# ...          ...         ...
# 1039  2023-12-26       52.01
# 1040  2023-12-27       52.82
# 1041  2023-12-28       54.01
# 1042  2023-12-29       53.80
# 1043  2023-12-30       53.75
#
# [1044 rows x 2 columns]

# %%
train_merged.head(2000)
# Out:
#         id        date  store_nbr               family  sales  onpromotion  \
# 0        0  2020-01-01          1           AUTOMOTIVE    0.0            0
# 1        1  2020-01-01          1            BABY CARE    0.0            0
# 2        2  2020-01-01          1               BEAUTY    0.0            0
# 3        3  2020-01-01          1            BEVERAGES    0.0            0
# 4        4  2020-01-01          1                BOOKS    0.0            0
# ...    ...         ...        ...                  ...    ...          ...
# 1995  1995  2020-01-02         15   HOME AND KITCHEN I    0.0            0
# 1996  1996  2020-01-02         15  HOME AND KITCHEN II    0.0            0
# 1997  1997  2020-01-02         15      HOME APPLIANCES    0.0            0
# 1998  1998  2020-01-02         15            HOME CARE    0.0            0
# 1999  1999  2020-01-02         15           LADIESWEAR    0.0            0
#
#       dcoilwtico
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1995       93.14
# 1996       93.14
# 1997       93.14
# 1998       93.14
# 1999       93.14
#
# [2000 rows x 7 columns]

# %%
train_merged['dcoilwtico'].mean()
# Out:
# np.float64(70.73858275520311)

# %%
train_merged.isna().sum()
# Out:
# id                  0
# date                0
# store_nbr           0
# family              0
# sales               0
# onpromotion         0
# dcoilwtico     798336
# dtype: int64

# %%
train_merged.shape
# Out:
# (2596374, 7)

# %%
test
# Out:
#             id        date  store_nbr                      family  onpromotion
# 0      2596374  2024-01-01          1                  AUTOMOTIVE            0
# 1      2596375  2024-01-01          1                   BABY CARE            0
# 2      2596376  2024-01-01          1                      BEAUTY            0
# 3      2596377  2024-01-01          1                   BEVERAGES            0
# 4      2596378  2024-01-01          1                       BOOKS            0
# ...        ...         ...        ...                         ...          ...
# 26725  2623099  2024-01-15          9                     POULTRY            1
# 26726  2623100  2024-01-15          9              PREPARED FOODS            1
# 26727  2623101  2024-01-15          9                     PRODUCE            7
# 26728  2623102  2024-01-15          9  SCHOOL AND OFFICE SUPPLIES            0
# 26729  2623103  2024-01-15          9                     SEAFOOD            1
#
# [26730 rows x 5 columns]

# %%
family_sales = train_merged.groupby('family')['sales'].sum().sort_values(ascending=False)

family_sales.plot(kind='bar', figsize=(12, 6), color='skyblue')
plt.title('Total Sales by Product Family')
plt.xlabel('Product Family')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(train_merged['dcoilwtico'], train_merged['sales'], alpha=0.5, color='red')
plt.title('Oil Price vs Sales')
plt.xlabel('Oil Price')
plt.ylabel('Sales')
plt.show()

# %%
plt.pie(train_merged['family'].value_counts(), autopct='%1.1f%%')
plt.title('Family Distribution')
plt.legend(title='family')
plt.show()

# %%
correlation_matrix = train_merged.pivot_table(index='date', columns='family', values='sales').corrwith(train_merged['dcoilwtico'])

# %%
train_merged['dcoilwtico'].fillna(method='ffill', inplace=True)
train_merged['dcoilwtico'].fillna(method='bfill', inplace=True)

# %%
train_merged
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2020-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2020-01-01          1                   BABY CARE     0.000
# 2              2  2020-01-01          1                      BEAUTY     0.000
# 3              3  2020-01-01          1                   BEVERAGES     0.000
# 4              4  2020-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 2596369  2596369  2023-12-31          9                     POULTRY   687.853
# 2596370  2596370  2023-12-31          9              PREPARED FOODS   100.405
# 2596371  2596371  2023-12-31          9                     PRODUCE  3091.356
# 2596372  2596372  2023-12-31          9  SCHOOL AND OFFICE SUPPLIES     2.000
# 2596373  2596373  2023-12-31          9                     SEAFOOD    13.000
#
#          onpromotion  dcoilwtico
# 0                  0       93.14
# 1                  0       93.14
# 2                  0       93.14
# 3                  0       93.14
# 4                  0       93.14
# ...              ...         ...
# 2596369            1       53.75
# 2596370            1       53.75
# 2596371            3       53.75
# 2596372            0       53.75
# 2596373            2       53.75
#
# [2596374 rows x 7 columns]

# %%
sales_trend = train_merged.groupby('date').agg({'sales': 'sum', 'dcoilwtico': 'mean'}).reset_index()

plt.figure(figsize=(14, 6))
plt.plot(sales_trend['date'], sales_trend['sales'], label='Total Sales', color='blue')
plt.plot(sales_trend['date'], sales_trend['dcoilwtico'], label='Oil Price', color='orange')
plt.legend()
plt.title('Sales and Oil Price Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.show()

# %%
# Step 1: Calculate total sales per family
family_sales_total = train_merged.groupby('family')['sales'].sum()

# Step 2: Calculate percentage contribution
total_sales = family_sales_total.sum()
family_sales_percentage = (family_sales_total / total_sales) * 100

# Display the contributions sorted in descending order
family_contribution = family_sales_percentage.sort_values(ascending=False)
print("Contribution of each family to total sales (in %):")
print(family_contribution)
# Out:
# Contribution of each family to total sales (in %):
# family
# GROCERY I                     32.557735
# BEVERAGES                     19.672096
# PRODUCE                       10.623870
# CLEANING                       9.326799
# DAIRY                          6.030285
# BREAD/BAKERY                   4.013243
# POULTRY                        3.077125
# MEATS                          3.018504
# PERSONAL CARE                  2.338156
# DELI                           2.299597
# EGGS                           1.497740
# FROZEN FOODS                   1.412864
# HOME CARE                      1.394045
# PREPARED FOODS                 0.859755
# LIQUOR,WINE,BEER               0.754225
# SEAFOOD                        0.198281
# GROCERY II                     0.187304
# HOME AND KITCHEN I             0.164617
# HOME AND KITCHEN II            0.131394
# CELEBRATION                    0.067662
# LINGERIE                       0.064489
# LADIESWEAR                     0.057325
# AUTOMOTIVE                     0.052739
# PLAYERS AND ELECTRONICS        0.047673
# LAWN AND GARDEN                0.039108
# BEAUTY                         0.030836
# PET SUPPLIES                   0.028401
# MAGAZINES                      0.021304
# SCHOOL AND OFFICE SUPPLIES     0.017800
# HARDWARE                       0.009793
# HOME APPLIANCES                0.003935
# BABY CARE                      0.000832
# BOOKS                          0.000468
# Name: sales, dtype: float64

# %%
impactful_families = family_contribution[family_contribution > 1].index

train_merged_filtered = train_merged[train_merged['family'].isin(impactful_families)]

print(f"Total families before filtering: {train_merged['family'].nunique()}")
print(f"Total families after filtering: {train_merged_filtered['family'].nunique()}")
print(f"Families removed: {set(train_merged['family'].unique()) - set(impactful_families)}")
# Out:
# Total families before filtering: 33
# Total families after filtering: 13
# Families removed: {'HOME AND KITCHEN II', 'LINGERIE', 'BOOKS', 'BABY CARE', 'GROCERY II', 'SEAFOOD', 'HARDWARE', 'HOME AND KITCHEN I', 'SCHOOL AND OFFICE SUPPLIES', 'PREPARED FOODS', 'LADIESWEAR', 'MAGAZINES', 'BEAUTY', 'PLAYERS AND ELECTRONICS', 'LIQUOR,WINE,BEER', 'HOME APPLIANCES', 'CELEBRATION', 'AUTOMOTIVE', 'PET SUPPLIES', 'LAWN AND GARDEN'}

# %%
# prompt: plot pie chart of impactful families as per their sales

# Assuming 'family_sales_percentage' is already calculated as in the previous code

plt.figure(figsize=(18, 8))
plt.pie(family_sales_percentage, labels=family_sales_percentage.index, autopct='%1.1f%%', startangle=90)
plt.title('Impactful Families Sales Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
train_merged
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2020-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2020-01-01          1                   BABY CARE     0.000
# 2              2  2020-01-01          1                      BEAUTY     0.000
# 3              3  2020-01-01          1                   BEVERAGES     0.000
# 4              4  2020-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 2596369  2596369  2023-12-31          9                     POULTRY   687.853
# 2596370  2596370  2023-12-31          9              PREPARED FOODS   100.405
# 2596371  2596371  2023-12-31          9                     PRODUCE  3091.356
# 2596372  2596372  2023-12-31          9  SCHOOL AND OFFICE SUPPLIES     2.000
# 2596373  2596373  2023-12-31          9                     SEAFOOD    13.000
#
#          onpromotion  dcoilwtico
# 0                  0       93.14
# 1                  0       93.14
# 2                  0       93.14
# 3                  0       93.14
# 4                  0       93.14
# ...              ...         ...
# 2596369            1       53.75
# 2596370            1       53.75
# 2596371            3       53.75
# 2596372            0       53.75
# 2596373            2       53.75
#
# [2596374 rows x 7 columns]

# %%
one_hot_encoded = pd.get_dummies(train_merged_filtered['family'], prefix='family')

# Concatenate the one-hot encoded columns back to the original dataframe
train_merged_filtered = pd.concat([train_merged_filtered, one_hot_encoded], axis=1)

# Verify the result
print(train_merged_filtered.head())
# Out:
#    id        date  store_nbr        family  sales  onpromotion  dcoilwtico  \
# 3   3  2020-01-01          1     BEVERAGES    0.0            0       93.14
# 5   5  2020-01-01          1  BREAD/BAKERY    0.0            0       93.14
# 7   7  2020-01-01          1      CLEANING    0.0            0       93.14
# 8   8  2020-01-01          1         DAIRY    0.0            0       93.14
# 9   9  2020-01-01          1          DELI    0.0            0       93.14
#
#    family_BEVERAGES  family_BREAD/BAKERY  family_CLEANING  family_DAIRY  \
# 3              True                False            False         False
# 5             False                 True            False         False
# 7             False                False             True         False
# 8             False                False            False          True
# 9             False                False            False         False
#
#    family_DELI  family_EGGS  family_FROZEN FOODS  family_GROCERY I  \
# 3        False        False                False             False
# 5        False        False                False             False
# 7        False        False                False             False
# 8        False        False                False             False
# 9         True        False                False             False
#
#    family_HOME CARE  family_MEATS  family_PERSONAL CARE  family_POULTRY  \
# 3             False         False                 False           False
# 5             False         False                 False           False
# 7             False         False                 False           False
# 8             False         False                 False           False
# 9             False         False                 False           False
#
#    family_PRODUCE
# 3           False
# 5           False
# 7           False
# 8           False
# 9           False

# %%
train_merged_filtered["date"] = pd.to_datetime(train_merged_filtered["date"])

# %%
train_merged_filtered=train_merged_filtered.drop(['family'],axis=1)

# %%
train_merged_filtered
# Out:
#               id       date  store_nbr     sales  onpromotion  dcoilwtico  \
# 3              3 2020-01-01          1     0.000            0       93.14
# 5              5 2020-01-01          1     0.000            0       93.14
# 7              7 2020-01-01          1     0.000            0       93.14
# 8              8 2020-01-01          1     0.000            0       93.14
# 9              9 2020-01-01          1     0.000            0       93.14
# ...          ...        ...        ...       ...          ...         ...
# 2596359  2596359 2023-12-31          9   515.000            7       53.75
# 2596365  2596365 2023-12-31          9   278.092            0       53.75
# 2596366  2596366 2023-12-31          9   516.000           13       53.75
# 2596369  2596369 2023-12-31          9   687.853            1       53.75
# 2596371  2596371 2023-12-31          9  3091.356            3       53.75
#
#          family_BEVERAGES  family_BREAD/BAKERY  family_CLEANING  family_DAIRY  \
# 3                    True                False            False         False
# 5                   False                 True            False         False
# 7                   False                False             True         False
# 8                   False                False            False          True
# 9                   False                False            False         False
# ...                   ...                  ...              ...           ...
# 2596359             False                False            False         False
# 2596365             False                False            False         False
# 2596366             False                False            False         False
# 2596369             False                False            False         False
# 2596371             False                False            False         False
#
#          family_DELI  family_EGGS  family_FROZEN FOODS  family_GROCERY I  \
# 3              False        False                False             False
# 5              False        False                False             False
# 7              False        False                False             False
# 8              False        False                False             False
# 9               True        False                False             False
# ...              ...          ...                  ...               ...
# 2596359        False        False                False             False
# 2596365        False        False                False             False
# 2596366        False        False                False             False
# 2596369        False        False                False             False
# 2596371        False        False                False             False
#
#          family_HOME CARE  family_MEATS  family_PERSONAL CARE  family_POULTRY  \
# 3                   False         False                 False           False
# 5                   False         False                 False           False
# 7                   False         False                 False           False
# 8                   False         False                 False           False
# 9                   False         False                 False           False
# ...                   ...           ...                   ...             ...
# 2596359              True         False                 False           False
# 2596365             False          True                 False           False
# 2596366             False         False                  True           False
# 2596369             False         False                 False            True
# 2596371             False         False                 False           False
#
#          family_PRODUCE
# 3                 False
# 5                 False
# 7                 False
# 8                 False
# 9                 False
# ...                 ...
# 2596359           False
# 2596365           False
# 2596366           False
# 2596369           False
# 2596371            True
#
# [1022814 rows x 19 columns]

# %%
train_merged_filtered['date'] = pd.to_datetime(train_merged_filtered['date'])
train_merged_filtered['date_as_int_yyyymmdd'] = train_merged_filtered['date'].dt.strftime('%Y%m%d').astype(int)

# %%
train_merged_filtered=train_merged_filtered.drop(['date','dcoilwtico'],axis=1)
train_merged_filtered
# Out:
#               id  store_nbr     sales  onpromotion  family_BEVERAGES  \
# 3              3          1     0.000            0              True
# 5              5          1     0.000            0             False
# 7              7          1     0.000            0             False
# 8              8          1     0.000            0             False
# 9              9          1     0.000            0             False
# ...          ...        ...       ...          ...               ...
# 2596359  2596359          9   515.000            7             False
# 2596365  2596365          9   278.092            0             False
# 2596366  2596366          9   516.000           13             False
# 2596369  2596369          9   687.853            1             False
# 2596371  2596371          9  3091.356            3             False
#
#          family_BREAD/BAKERY  family_CLEANING  family_DAIRY  family_DELI  \
# 3                      False            False         False        False
# 5                       True            False         False        False
# 7                      False             True         False        False
# 8                      False            False          True        False
# 9                      False            False         False         True
# ...                      ...              ...           ...          ...
# 2596359                False            False         False        False
# 2596365                False            False         False        False
# 2596366                False            False         False        False
# 2596369                False            False         False        False
# 2596371                False            False         False        False
#
#          family_EGGS  family_FROZEN FOODS  family_GROCERY I  family_HOME CARE  \
# 3              False                False             False             False
# 5              False                False             False             False
# 7              False                False             False             False
# 8              False                False             False             False
# 9              False                False             False             False
# ...              ...                  ...               ...               ...
# 2596359        False                False             False              True
# 2596365        False                False             False             False
# 2596366        False                False             False             False
# 2596369        False                False             False             False
# 2596371        False                False             False             False
#
#          family_MEATS  family_PERSONAL CARE  family_POULTRY  family_PRODUCE  \
# 3               False                 False           False           False
# 5               False                 False           False           False
# 7               False                 False           False           False
# 8               False                 False           False           False
# 9               False                 False           False           False
# ...               ...                   ...             ...             ...
# 2596359         False                 False           False           False
# 2596365          True                 False           False           False
# 2596366         False                  True           False           False
# 2596369         False                 False            True           False
# 2596371         False                 False           False            True
#
#          date_as_int_yyyymmdd
# 3                    20200101
# 5                    20200101
# 7                    20200101
# 8                    20200101
# 9                    20200101
# ...                       ...
# 2596359              20231231
# 2596365              20231231
# 2596366              20231231
# 2596369              20231231
# 2596371              20231231
#
# [1022814 rows x 18 columns]

# %% [markdown]
# Decision Tree Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Split data into train (60%), validation (20%), and test (20%) sets
train_data, temp_data = train_test_split(
    train_merged_filtered, test_size=0.4, random_state=42
)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# Separate features and target for each set
X_train, y_train = train_data.drop(columns=['sales']), train_data['sales']
X_val, y_val = val_data.drop(columns=['sales']), val_data['sales']
X_test, y_test = test_data.drop(columns=['sales']), test_data['sales']

# Initialize and train the Decision Tree Regressor
dt_reg = DecisionTreeRegressor(max_depth=10, random_state=42)
dt_reg.fit(X_train, y_train)

# Evaluate the model on the training set
y_train_pred = dt_reg.predict(X_train)
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
r2_train = r2_score(y_train, y_train_pred)

# Evaluate the model on the validation set
y_val_pred = dt_reg.predict(X_val)
rmse_val = np.sqrt(mean_squared_error(y_val, y_val_pred))
r2_val = r2_score(y_val, y_val_pred)

# Evaluate the model on the test set
y_test_pred = dt_reg.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
r2_test = r2_score(y_test, y_test_pred)

# Print RMSE and R² results for all sets
print(f"Training RMSE: {rmse_train:.2f}")
print(f"Validation RMSE: {rmse_val:.2f}")
print(f"Test RMSE: {rmse_test:.2f}")

print(f"Training R² Score: {r2_train:.4f}")
print(f"Validation R² Score: {r2_val:.4f}")
print(f"Test R² Score: {r2_test:.4f}")
# Out:
# Training RMSE: 636.77
# Validation RMSE: 717.39
# Test RMSE: 712.00
# Training R² Score: 0.8306
# Validation R² Score: 0.7940
# Test R² Score: 0.7895

# %% [markdown]
# Random Forest Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Split data into train (60%), validation (20%), and test (20%) sets
train_data, temp_data = train_test_split(
    train_merged_filtered, test_size=0.4, random_state=42
)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# Separate features and target for each set
X_train, y_train = train_data.drop(columns=['sales']), train_data['sales']
X_val, y_val = val_data.drop(columns=['sales']), val_data['sales']
X_test, y_test = test_data.drop(columns=['sales']), test_data['sales']

# Initialize and train the Decision Tree Regressor
rf_reg = RandomForestRegressor(max_depth=10, random_state=42)
rf_reg.fit(X_train, y_train)

# Evaluate the model on the training set
y_train_pred = rf_reg.predict(X_train)
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
r2_train = r2_score(y_train, y_train_pred)

# Evaluate the model on the validation set
y_val_pred = rf_reg.predict(X_val)
rmse_val = np.sqrt(mean_squared_error(y_val, y_val_pred))
r2_val = r2_score(y_val, y_val_pred)

# Evaluate the model on the test set
y_test_pred = rf_reg.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
r2_test = r2_score(y_test, y_test_pred)

# Print RMSE and R² results for all sets
print(f"Training RMSE: {rmse_train:.2f}")
print(f"Validation RMSE: {rmse_val:.2f}")
print(f"Test RMSE: {rmse_test:.2f}")

print(f"Training R² Score: {r2_train:.4f}")
print(f"Validation R² Score: {r2_val:.4f}")
print(f"Test R² Score: {r2_test:.4f}")
# Out:
# Training RMSE: 616.34
# Validation RMSE: 695.14
# Test RMSE: 683.17
# Training R² Score: 0.8413
# Validation R² Score: 0.8066
# Test R² Score: 0.8062

# %%
one_hot_encoded = pd.get_dummies(test['family'], prefix='family')

# Concatenate the one-hot encoded columns back to the original dataframe
test = pd.concat([test, one_hot_encoded], axis=1)

# Verify the result
test_filtered=test.drop(['family'],axis=1)
print(test_filtered.head())
# Out:
#         id        date  store_nbr  onpromotion  family_AUTOMOTIVE  \
# 0  2596374  2024-01-01          1            0               True
# 1  2596375  2024-01-01          1            0              False
# 2  2596376  2024-01-01          1            0              False
# 3  2596377  2024-01-01          1            0              False
# 4  2596378  2024-01-01          1            0              False
#
#    family_BABY CARE  family_BEAUTY  family_BEVERAGES  family_BOOKS  \
# 0             False          False             False         False
# 1              True          False             False         False
# 2             False           True             False         False
# 3             False          False              True         False
# 4             False          False             False          True
#
#    family_BREAD/BAKERY  ...  family_MAGAZINES  family_MEATS  \
# 0                False  ...             False         False
# 1                False  ...             False         False
# 2                False  ...             False         False
# 3                False  ...             False         False
# 4                False  ...             False         False
#
#    family_PERSONAL CARE  family_PET SUPPLIES  family_PLAYERS AND ELECTRONICS  \
# 0                 False                False                           False
# 1                 False                False                           False
# 2                 False                False                           False
# 3                 False                False                           False
# 4                 False                False                           False
#
#    family_POULTRY  family_PREPARED FOODS  family_PRODUCE  \
# 0           False                  False           False
# 1           False                  False           False
# 2           False                  False           False
# 3           False                  False           False
# 4           False                  False           False
#
#    family_SCHOOL AND OFFICE SUPPLIES  family_SEAFOOD
# 0                              False           False
# 1                              False           False
# 2                              False           False
# 3                              False           False
# 4                              False           False
#
# [5 rows x 37 columns]

# %%
test_filtered['date'] = pd.to_datetime(test_filtered['date'])
test_filtered['date_as_int_yyyymmdd'] = test_filtered['date'].dt.strftime('%Y%m%d').astype(int)

# %%
test_filtered
# Out:
#             id       date  store_nbr  onpromotion  family_AUTOMOTIVE  \
# 0      2596374 2024-01-01          1            0               True
# 1      2596375 2024-01-01          1            0              False
# 2      2596376 2024-01-01          1            0              False
# 3      2596377 2024-01-01          1            0              False
# 4      2596378 2024-01-01          1            0              False
# ...        ...        ...        ...          ...                ...
# 26725  2623099 2024-01-15          9            1              False
# 26726  2623100 2024-01-15          9            1              False
# 26727  2623101 2024-01-15          9            7              False
# 26728  2623102 2024-01-15          9            0              False
# 26729  2623103 2024-01-15          9            1              False
#
#        family_BABY CARE  family_BEAUTY  family_BEVERAGES  family_BOOKS  \
# 0                 False          False             False         False
# 1                  True          False             False         False
# 2                 False           True             False         False
# 3                 False          False              True         False
# 4                 False          False             False          True
# ...                 ...            ...               ...           ...
# 26725             False          False             False         False
# 26726             False          False             False         False
# 26727             False          False             False         False
# 26728             False          False             False         False
# 26729             False          False             False         False
#
#        family_BREAD/BAKERY  ...  family_MEATS  family_PERSONAL CARE  \
# 0                    False  ...         False                 False
# 1                    False  ...         False                 False
# 2                    False  ...         False                 False
# 3                    False  ...         False                 False
# 4                    False  ...         False                 False
# ...                    ...  ...           ...                   ...
# 26725                False  ...         False                 False
# 26726                False  ...         False                 False
# 26727                False  ...         False                 False
# 26728                False  ...         False                 False
# 26729                False  ...         False                 False
#
#        family_PET SUPPLIES  family_PLAYERS AND ELECTRONICS  family_POULTRY  \
# 0                    False                           False           False
# 1                    False                           False           False
# 2                    False                           False           False
# 3                    False                           False           False
# 4                    False                           False           False
# ...                    ...                             ...             ...
# 26725                False                           False            True
# 26726                False                           False           False
# 26727                False                           False           False
# 26728                False                           False           False
# 26729                False                           False           False
#
#        family_PREPARED FOODS  family_PRODUCE  \
# 0                      False           False
# 1                      False           False
# 2                      False           False
# 3                      False           False
# 4                      False           False
# ...                      ...             ...
# 26725                  False           False
# 26726                   True           False
# 26727                  False            True
# 26728                  False           False
# 26729                  False           False
#
#        family_SCHOOL AND OFFICE SUPPLIES  family_SEAFOOD  date_as_int_yyyymmdd
# 0                                  False           False              20240101
# 1                                  False           False              20240101
# 2                                  False           False              20240101
# 3                                  False           False              20240101
# 4                                  False           False              20240101
# ...                                  ...             ...                   ...
# 26725                              False           False              20240115
# 26726                              False           False              20240115
# 26727                              False           False              20240115
# 26728                               True           False              20240115
# 26729                              False            True              20240115
#
# [26730 rows x 38 columns]

# %%
test_filtered=test_filtered.drop(['date'],axis=1)

# %%
columns_to_keep = [
    'id','store_nbr', 'onpromotion', 'family_BEVERAGES',
    'family_BREAD/BAKERY', 'family_CLEANING', 'family_DAIRY', 'family_DELI',
    'family_EGGS', 'family_FROZEN FOODS', 'family_GROCERY I',
    'family_HOME CARE', 'family_MEATS', 'family_PERSONAL CARE',
    'family_POULTRY', 'family_PRODUCE', 'date_as_int_yyyymmdd'
]

# Retain only the required columns in test_filtered
test_filtered = test_filtered[columns_to_keep]

# %%
test_filtered
# Out:
#             id  store_nbr  onpromotion  family_BEVERAGES  family_BREAD/BAKERY  \
# 0      2596374          1            0             False                False
# 1      2596375          1            0             False                False
# 2      2596376          1            0             False                False
# 3      2596377          1            0              True                False
# 4      2596378          1            0             False                False
# ...        ...        ...          ...               ...                  ...
# 26725  2623099          9            1             False                False
# 26726  2623100          9            1             False                False
# 26727  2623101          9            7             False                False
# 26728  2623102          9            0             False                False
# 26729  2623103          9            1             False                False
#
#        family_CLEANING  family_DAIRY  family_DELI  family_EGGS  \
# 0                False         False        False        False
# 1                False         False        False        False
# 2                False         False        False        False
# 3                False         False        False        False
# 4                False         False        False        False
# ...                ...           ...          ...          ...
# 26725            False         False        False        False
# 26726            False         False        False        False
# 26727            False         False        False        False
# 26728            False         False        False        False
# 26729            False         False        False        False
#
#        family_FROZEN FOODS  family_GROCERY I  family_HOME CARE  family_MEATS  \
# 0                    False             False             False         False
# 1                    False             False             False         False
# 2                    False             False             False         False
# 3                    False             False             False         False
# 4                    False             False             False         False
# ...                    ...               ...               ...           ...
# 26725                False             False             False         False
# 26726                False             False             False         False
# 26727                False             False             False         False
# 26728                False             False             False         False
# 26729                False             False             False         False
#
#        family_PERSONAL CARE  family_POULTRY  family_PRODUCE  \
# 0                     False           False           False
# 1                     False           False           False
# 2                     False           False           False
# 3                     False           False           False
# 4                     False           False           False
# ...                     ...             ...             ...
# 26725                 False            True           False
# 26726                 False           False           False
# 26727                 False           False            True
# 26728                 False           False           False
# 26729                 False           False           False
#
#        date_as_int_yyyymmdd
# 0                  20240101
# 1                  20240101
# 2                  20240101
# 3                  20240101
# 4                  20240101
# ...                     ...
# 26725              20240115
# 26726              20240115
# 26727              20240115
# 26728              20240115
# 26729              20240115
#
# [26730 rows x 17 columns]

# %%
test_data = test_filtered.copy()  # Replace with actual test dataset if not already loaded

# Predict sales using the trained Random Forest model
test_data['sales'] = rf_reg.predict(test_data)

# Create the final DataFrame with 'id' and 'sales' columns
output = test_data[['id', 'sales']]
output
# Save to CSV
output.to_csv('sales_predictions.csv', index=False)

print("Predictions saved to 'sales_predictions.csv'")
output
# Out:
# Predictions saved to 'sales_predictions.csv'
#             id        sales
# 0      2596374   269.954004
# 1      2596375   269.954004
# 2      2596376   269.954004
# 3      2596377  2239.788800
# 4      2596378   269.954004
# ...        ...          ...
# 26725  2623099   508.605565
# 26726  2623100   269.954004
# 26727  2623101  1375.144490
# 26728  2623102   269.954004
# 26729  2623103   269.954004
#
# [26730 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(),
    'XGBoost': XGBRegressor()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    rmse = mean_squared_error(y_test, preds)
    mae = mean_absolute_error(y_test, preds)
    r2 = r2_score(y_test, preds)

    print(f"\n{name}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"R² Score: {r2:.4f}")
# Out:
# Linear Regression
# RMSE: 1341817.8802
# MAE: 563.7789
# R² Score: 0.4428
#
# Random Forest
# RMSE: 341323.2073
# MAE: 192.4955
# R² Score: 0.8583
#
# XGBoost
# RMSE: 364893.4090
# MAE: 238.7902
# R² Score: 0.8485

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

xgb = XGBRegressor()

param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid,
                           cv=3, scoring='neg_root_mean_squared_error', n_jobs=-1, verbose=1)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best RMSE (CV):", -grid_search.best_score_)

best_xgb = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 150}
# Best RMSE (CV): 529.961329253245

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Predictions with the best tuned XGBoost model
preds = best_xgb.predict(X_test)

# Regression metrics
rmse = mean_squared_error(y_test, preds)
mae = mean_absolute_error(y_test, preds)
r2 = r2_score(y_test, preds)

print("Tuned XGBoost Performance on Test Set:")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R² Score: {r2:.4f}")

# Plot Actual vs Predicted Prices
plt.figure(figsize=(8,6))
plt.plot(y_test.values, label='Actual Prices')
plt.plot(preds, label='Predicted Prices', alpha=0.7)
plt.title('Actual vs Predicted Oil Prices')
plt.xlabel('Samples')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# Plot Residuals
residuals = y_test - preds
plt.figure(figsize=(8,5))
sns.histplot(residuals, kde=True, bins=30, color='coral')
plt.title("Residuals Distribution")
plt.xlabel("Residual (Actual - Predicted)")
plt.tight_layout()
plt.show()
# Out:
# Tuned XGBoost Performance on Test Set:
# RMSE: 333684.7966
# MAE: 217.8360
# R² Score: 0.8614

# %%
import matplotlib.pyplot as plt
import seaborn as sns

importances = best_xgb.feature_importances_
feature_names = X_train.columns
feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(data=feature_imp_df, x='Importance', y='Feature', palette='viridis')
plt.title("XGBoost Feature Importances")
plt.tight_layout()
plt.show()

# %%
# Predictions on train set
train_preds = best_xgb.predict(X_train)

# Regression metrics on train set
train_rmse = mean_squared_error(y_train, train_preds)
train_mae = mean_absolute_error(y_train, train_preds)
train_r2 = r2_score(y_train, train_preds)

# Print metrics for both train and test sets
print("Training Set Performance:")
print(f"RMSE: {train_rmse:.4f}")
print(f"MAE: {train_mae:.4f}")
print(f"R² Score: {train_r2:.4f}")

# Test set performance (already calculated)
print("\nTest Set Performance:")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Training Set Performance:
# RMSE: 248927.9664
# MAE: 211.3974
# R² Score: 0.8960
#
# Test Set Performance:
# RMSE: 333684.7966
# MAE: 217.8360
# R² Score: 0.8614
